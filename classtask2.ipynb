# %% [markdown]
# ### Class Task 3

# %% [markdown]
# Let
#
# $$
# A = \begin{bmatrix}
# 2 & -1 \\
# 0 & 3
# \end{bmatrix}
# $$
#
#
#
# $$
# B = \begin{bmatrix}
# 1 & 4 \\
# -2 & 5
# \end{bmatrix}
# $$
#
#
#
#
#
#
#
#
#
#
# Scalars (c = 2), (d = 3)

# %% [markdown]
# 1 . Compute the following : (cA), (dB) , (c + d)A

# %% [markdown]
# 1a.        (cA)
#
#                 c = 2
# $$
# A = \begin{bmatrix}
# 2 & -1 \\
# 0 & 3
# \end{bmatrix}
# $$
#
#
# $$
# c(A) = \begin{bmatrix}
# (2*2) & (2*-1) \\
# (2*0) & (2*3)
# \end{bmatrix}
# $$
#
#
#  $$
# c(A) = \begin{bmatrix}
# 4 & -2 \\
# 0 & 6
# \end{bmatrix}
# $$

# %% [markdown]
# 1b.     (dB)
#
#                 d = 3
# $$
# B = \begin{bmatrix}
# 1 & 4 \\
# -2 & 5
# \end{bmatrix}
# $$
#
#
# $$
# d(B) = \begin{bmatrix}
# (3*1) & (3*4) \\
# (3*-2) & (3*5)
# \end{bmatrix}
# $$
#
#
#  $$
# d(B) = \begin{bmatrix}
# 3 & 12 \\
# -6 & 15
# \end{bmatrix}
# $$

# %% [markdown]
# 1c.        (c + d)A
#
#                 c = 2  d = 3
#                 c + d = 5
#                 5(A)
# $$
# A = \begin{bmatrix}
# 2 & -1 \\
# 0 & 3
# \end{bmatrix}
# $$
#
#
# $$
# 5(A) = \begin{bmatrix}
# (5*2) & (5*-1) \\
# (5*0) & (5*3)
# \end{bmatrix}
# $$
#
#
#  $$
# (c + d)(A) = \begin{bmatrix}
# 10 & -5 \\
# 0 & 15
# \end{bmatrix}
# $$

# %% [markdown]
# ### 2. Using the results gotten , Verify the scalar multiplication properties.
#
# Scalar Multiplication Properties are: <br> <br>
# a. Associativity Property:
# (c .  d)A = c . (dA)
#
# b. Distributivity Over Matrix Addition:
# c(A + B) = cA + cB
#
# c. Distributivity Over Scalar Addition:
# (c + d)A = cA + dA

# %% [markdown]
# ### a. Associativity Property:
#
# (c . d)A = c . (dA)
#
# Where c = 2 , d = 3, and
# $$
# A = \begin{bmatrix}
# 2 & -1 \\
# 0 & 3
# \end{bmatrix}
# $$
#
# (c . d)A = (2 . 3)A = 6(A)
#
# 6(A) = 2 . (3A)
#
#
#
# $$
# 6(A) = \begin{bmatrix}
# (6*2) & (6*-1) \\
# (6*0) & (6*3)
# \end{bmatrix}
# $$
#
# The first equation (c .d)A answer
#
# $$
# (6)A = \begin{bmatrix}
# 12 & -6 \\
# 0 & 18
# \end{bmatrix}
# $$
#
#
#
#
#
#   2  (3A)
#
# $$
# 3(A) = \begin{bmatrix}
# (3*2) & (3*-1) \\
# (3*0) & (3*3)
# \end{bmatrix}
# $$
#
#
#
# $$
# (3)A = \begin{bmatrix}
# 6 & -3 \\
# 0 & 9
# \end{bmatrix}
# $$
#
#
# 2 * 3(A):
#
# $$
# 2.(3A) = \begin{bmatrix}
# 2.6 & 2.-3 \\
# 2.0 & 2.9
# \end{bmatrix}
# $$
#
# The second equation c . (dA) answer:
#
# $$
# c . (dA) = \begin{bmatrix}
# 12 & -6 \\
# 0 & 18
# \end{bmatrix}
# $$
#
#
#
# Since (c . d )A  = c . (dA) , the Associative Property of Scalar Multiplication is verified.

# %% [markdown]
# ### b. Distributivity Property Over Matrix Addition:
#
# c(A + B) = cA + cB
#
# Where c = 2 , d = 3, and
# $$
# A = \begin{bmatrix}
# 2 & -1 \\
# 0 & 3
# \end{bmatrix}
# $$
# +
#
# $$
# B = \begin{bmatrix}
# 1 & 4 \\
# -2 & 5
# \end{bmatrix}
# $$
#
#
#
#
#
#
# c(A + B) = 2(A + B)
#
#
#   $$
# (A + B) = \begin{bmatrix}
# (2 + 1) & (-1 + 4) \\
# (0 + -2) & (3 + 5)
# \end{bmatrix}
# $$
#
#
#
#
#  (A + B) answer:
#
# $$
# (A + B) = \begin{bmatrix}
# 3 & 3 \\
# -2 & 8
# \end{bmatrix}
# $$
#
#
#
#
#
#   2  (A + B)
#
# $$
# 2(A ) = \begin{bmatrix}
# (2*3) & (2*3) \\
# (2*-2) & (2*8)
# \end{bmatrix}
# $$
#
# <br>
# The answer for the first equation c(A + B):
#
#
# $$
# 2(A + B) = \begin{bmatrix}
# 6 & 6 \\
# -4 & 16
# \end{bmatrix}
# $$
#
#
#
#
# cA + cB
#
#
# <br>
#
# $$
# c(A) = \begin{bmatrix}
# (2*2) & (2*-1) \\
# (2*0) & (2*3)
# \end{bmatrix}
# $$
#
#
#  $$
# c(A) = \begin{bmatrix}
# 4 & -2 \\
# 0 & 6
# \end{bmatrix}
# $$
#
#
# <br>
#
# $$
# c(B) = \begin{bmatrix}
# (2*1) & (2*4) \\
# (2*-2) & (2*5)
# \end{bmatrix}
# $$
#
#
#  $$
# c(B) = \begin{bmatrix}
# 2 & 8 \\
# -4 & 10
# \end{bmatrix}
# $$
#
#
#
# <br>
#
# cA + cB
#
#
#
# $$
# c(A) =
# \begin{bmatrix}
# 4 & -2 \\
# 0 & 6
# \end{bmatrix}
# \quad+\quad
# c(B) = \begin{bmatrix}
# 2 & 8 \\
# -4 & 10
# \end{bmatrix}
# $$
#
# The answer to the second equation is :
#
# c(A) + C(B):
#
# $$
# c(A) + C(B) = \begin{bmatrix}
# 6 & 6 \\
# -4 & 16
# \end{bmatrix}
#
#
#
#
#
# Since C(A + B )  = cA + cB
#
# the Distributivity Property of Matrix Addition is
#
# verified.

# %% [markdown]
# ### b. Distributivity Property Over Scalar Addition:
#
# (c + d)A = cA + dA
#
#
#  (c + d)A
#
#                 c = 2  d = 3
#                 c + d = 5
#                 5(A)
# $$
# A = \begin{bmatrix}
# 2 & -1 \\
# 0 & 3
# \end{bmatrix}
# $$
#
#
# $$
# 5(A) = \begin{bmatrix}
# (5*2) & (5*-1) \\
# (5*0) & (5*3)
# \end{bmatrix}
# $$
#
#
# The answer to the first equation:
#
#  $$
# (c + d)(A) = \begin{bmatrix}
# 10 & -5 \\
# 0 & 15
# \end{bmatrix}
# $$
#
#
#
#
# cA + dA
#
#
#  $$
# c(A) = \begin{bmatrix}
# (2*2) & (2*-1) \\
# (2*0) & (2*3)
# \end{bmatrix}
# $$
#
#
#  $$
# c(A) = \begin{bmatrix}
# 4 & -2 \\
# 0 & 6
# \end{bmatrix}
# $$
#
#
#
#
#
# $$
# 3(A) = \begin{bmatrix}
# (3*2) & (3*-1) \\
# (3*0) & (3*3)
# \end{bmatrix}
# $$
#
#
#
# $$
# (3)A = \begin{bmatrix}
# 6 & -3 \\
# 0 & 9
# \end{bmatrix}
# $$
#
#
# The answer to the second equation:
#
#
# $$
# cA + dA =\begin{bmatrix}
# 10 & -5 \\
# 0 & 15
# \end{bmatrix}
#
#
#
#
#
#
# Since (c + d)A  = cA + dA
#
# the Distributivity Property of Scalar Addition is
#
# verified.

# %% [markdown]
# #### c. Find the transpose of both matrices:
#
#
#
# $$
# A = \begin{bmatrix}
# 2 & -1 \\
# 0 & 3
# \end{bmatrix}
#
# The transpose of A
#
#
#
# $$
# (3)A = \begin{bmatrix}
# 6 & -3 \\
# 0 & 9
# \end{bmatrix}
# $$

# %% [markdown]
# #### c. Find the transpose of both matrices:
#
# ###### Transpose of matrix A:
#
# $$
# transpose(A) = \begin{bmatrix}
# 2 & 1 \\
# 0 & 3
# \end{bmatrix}

# %% [markdown]
# ###### Transpose of matrix B:
#
#
# $$
# transpose(B) = \begin{bmatrix}
# 1 & -2 \\
# 4 & 5
# \end{bmatrix}

# %% [markdown]
# #### Check if (A) and (B) are invertible by computing their determinants.
#
#
# a. det(A) = (2 . 3) - (-1 . 0) = 6 - 0 = 6
#
# Since det(A) != 0, then the matrix is invertible.
# <br>
#
#
#
# b. det(B) = (1 . 5) - (4 . -2) = 5 - (-8) = 13
#
# Since det(B) != 0, then the matrix is invertible.

# %% [markdown]
# #### If they are invertible, find inverse of A and B
#
#
# Inverse(A) :
# $$
# 1/6 . \begin{bmatrix}
# 3 & 0 \\
# 1 & 2
# \end{bmatrix}
#
#
#
#
#
#
#
# % 1\2 & 0 \\
# % 1\6 & 1\3

# %% [markdown]
# Inverse(A) :
# $$
# Inverse(A) =  \begin{bmatrix}
# 1/2 & 0 \\
# 1/6 & 1/3
# \end{bmatrix}

# %% [markdown]
# Inverse(B) :
# $$
# 1/13 . \begin{bmatrix}
# 5 & -4 \\
# 2 & 1
# \end{bmatrix}

# %% [markdown]
# Inverse(B) :
# $$
# Inverse(B) =  \begin{bmatrix}
# 5/13 & -4/13 \\
# 2/13 & 1/13
# \end{bmatrix}
